# %%
import pandas as pd
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
import numpy as np
from pyspark.sql.functions import col
from pyspark.sql.functions import lit

# %%
from pyspark.sql.types import IntegerType
from pyspark.ml.feature import *

# %%
from pyspark.ml.feature import StopWordsRemover
from pyspark.ml.classification import *
from pyspark.ml.evaluation import *

# %%
from pyspark.ml import Pipeline

# %%
dataset1 =spark.read.format('csv').options(header=True, inferSchema=True).load("dataset.csv")

# %%
df_en =dataset1.select("English")
df_en=df_en.dropna()

# %%
df_fr =dataset1.select("French")
df_fr=df_fr.dropna()

# %%
data_eng = df_en.select(col("English").alias("text"))
data_fr = df_fr.select(col("French").alias("text"))

# %%
df_en= data_eng.withColumn("label", lit(1))
df_fr = data_fr.withColumn("label", lit(0))

# %%
#on tokenise les deux ensembles
tokenizer_df_en = Tokenizer(inputCol="text", outputCol="text_token") 
token_df_en=tokenizer_df_en.transform(df_en)

# %%
tokenizer_df_fr = Tokenizer(inputCol="text", outputCol="text_token") 
token_df_fr=tokenizer_df_fr.transform(df_fr)

# %%
import nltk.corpus 
from nltk.corpus import stopwords
nltk.download('stopwords')
stopword_en= stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
nltk.download('stopwords')
stopword_fr= stopwords.words('french')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
cleaned_df_en=StopWordsRemover(stopWords=stopword_en, inputCol="text_token", outputCol="text_cleaned")
df_en_cleaned=cleaned_df_en.transform(token_df_en)

# %%
cleaned_df_fr=StopWordsRemover(stopWords=stopword_fr,inputCol="text_token", outputCol="text_cleaned")
df_fr_cleaned=cleaned_df_fr.transform(token_df_fr)

# %%
#on divise le dataframe francais en ensemble de 
train_fr,test_fr = df_fr_cleaned.randomSplit([0.8,0.2])
train_en,test_en = df_en_cleaned.randomSplit([0.8,0.2])

# %%
#concatener les 2 dataframes d'entrainement
train= train_fr.union(train_en)

# %%
#concatener les 2 dataframes de test
test= test_fr.union(test_en)

# %%
train = train.withColumn("label",train["label"].cast(IntegerType()))
test = test.withColumn("label",test["label"].cast(IntegerType()))

# %%
ngram=NGram(n=2, inputCol="text_cleaned", outputCol="text_ngram")
ngram_train=ngram.transform(train)

# %%
ngram=NGram(n=2, inputCol="text_cleaned", outputCol="text_ngram")
ngram_test=ngram.transform(test)

# %%
hashingtf_train=HashingTF(inputCol="text_ngram", outputCol="text_hashing")
hashingtf_train.setNumFeatures(10000)
train_hash=hashingtf_train.transform(ngram_train)

# %%
hashingtf_test=HashingTF(inputCol="text_ngram", outputCol="text_hashing")
hashingtf_test.setNumFeatures(10000)
test_hash=hashingtf_test.transform(ngram_test)

# %%
idf_train = IDF(minDocFreq = 3, inputCol="text_hashing", outputCol="text_idf")
Model_train= idf_train.fit(train_hash)
train_idf = Model_train.transform(train_hash)

# %%
idf_test = IDF(minDocFreq = 3, inputCol="text_hashing", outputCol="text_idf")
Model_test = idf_test.fit(test_hash)
test_idf = Model_test.transform(test_hash)

# %%
train_final=train_idf.select("label","text_idf")
test_final=test_idf.select("label","text_idf")

# %%
lr = LogisticRegression(featuresCol="text_idf", labelCol="label")

# %%
training=lr.fit(train_final)

# %%
model_result=training.transform(test_final)

# %%
evaluator=BinaryClassificationEvaluator(rawPredictionCol="rawPrediction",labelCol="label", metricName="areaUnderPR")

# %%
evaluator.evaluate(model_result)
# Out:
# 0.8481775618172201

# %%
model_result.groupby('rawPrediction').count().collect()
# Out:
# [Row(rawPrediction=DenseVector([1.164, -1.164]), count=1),
#  Row(rawPrediction=DenseVector([-0.531, 0.531]), count=1),
#  Row(rawPrediction=DenseVector([-0.4272, 0.4272]), count=1),
#  Row(rawPrediction=DenseVector([-1.0806, 1.0806]), count=1),
#  Row(rawPrediction=DenseVector([-0.7222, 0.7222]), count=1),
#  Row(rawPrediction=DenseVector([3.9618, -3.9618]), count=1),
#  Row(rawPrediction=DenseVector([2.3382, -2.3382]), count=1),
#  Row(rawPrediction=DenseVector([0.6853, -0.6853]), count=1),
#  Row(rawPrediction=DenseVector([2.1922, -2.1922]), count=1),
#  Row(rawPrediction=DenseVector([-0.5199, 0.5199]), count=1),
#  Row(rawPrediction=DenseVector([-0.9744, 0.9744]), count=1),
#  Row(rawPrediction=DenseVector([8.3248, -8.3248]), count=1),
#  Row(rawPrediction=DenseVector([3.9352, -3.9352]), count=1),
#  Row(rawPrediction=DenseVector([-0.8477, 0.8477]), count=1),
#  Row(rawPrediction=DenseVector([-0.0003, 0.0003]), count=1),
#  Row(rawPrediction=DenseVector([-0.6526, 0.6526]), count=1),
#  Row(rawPrediction=DenseVector([0.5286, -0.5286]), count=1),
#  Row(rawPrediction=DenseVector([3.1929, -3.1929]), count=1),
#  Row(rawPrediction=DenseVector([0.4568, -0.4568]), count=1),
#  Row(rawPrediction=DenseVector([1.4599, -1.4599]), count=1),
#  Row(rawPrediction=DenseVector([2.7678, -2.7678]), count=1),
#  Row(rawPrediction=DenseVector([3.8282, -3.8282]), count=1),
#  Row(rawPrediction=DenseVector([1.146, -1.146]), count=1),
#  Row(rawPrediction=DenseVector([3.4562, -3.4562]), count=1),
#  Row(rawPrediction=DenseVector([1.8941, -1.8941]), count=1),
#  Row(rawPrediction=DenseVector([3.4948, -3.4948]), count=1),
#  Row(rawPrediction=DenseVector([-0.3954, 0.3954]), count=5),
#  Row(rawPrediction=DenseVector([5.9982, -5.9982]), count=1),
#  Row(rawPrediction=DenseVector([3.5863, -3.5863]), count=1),
#  Row(rawPrediction=DenseVector([0.7234, -0.7234]), count=1),
#  Row(rawPrediction=DenseVector([0.0865, -0.0865]), count=1),
#  Row(rawPrediction=DenseVector([1.6179, -1.6179]), count=1),
#  Row(rawPrediction=DenseVector([1.6293, -1.6293]), count=1),
#  Row(rawPrediction=DenseVector([0.0061, -0.0061]), count=1),
#  Row(rawPrediction=DenseVector([0.1486, -0.1486]), count=1),
#  Row(rawPrediction=DenseVector([-0.8013, 0.8013]), count=1),
#  Row(rawPrediction=DenseVector([-0.6752, 0.6752]), count=1),
#  Row(rawPrediction=DenseVector([3.367, -3.367]), count=1),
#  Row(rawPrediction=DenseVector([-0.4909, 0.4909]), count=1),
#  Row(rawPrediction=DenseVector([-1.2963, 1.2963]), count=1),
#  Row(rawPrediction=DenseVector([-0.7538, 0.7538]), count=1),
#  Row(rawPrediction=DenseVector([-0.3822, 0.3822]), count=2),
#  Row(rawPrediction=DenseVector([3.9951, -3.9951]), count=1),
#  Row(rawPrediction=DenseVector([1.1374, -1.1374]), count=1),
#  Row(rawPrediction=DenseVector([-0.659, 0.659]), count=1),
#  Row(rawPrediction=DenseVector([1.1842, -1.1842]), count=1),
#  Row(rawPrediction=DenseVector([1.3577, -1.3577]), count=1),
#  Row(rawPrediction=DenseVector([-0.442, 0.442]), count=1),
#  Row(rawPrediction=DenseVector([1.2449, -1.2449]), count=1),
#  Row(rawPrediction=DenseVector([1.8193, -1.8193]), count=1),
#  Row(rawPrediction=DenseVector([-0.5038, 0.5038]), count=1),
#  Row(rawPrediction=DenseVector([2.8303, -2.8303]), count=1),
#  Row(rawPrediction=DenseVector([5.6503, -5.6503]), count=1),
#  Row(rawPrediction=DenseVector([-0.8052, 0.8052]), count=1),
#  Row(rawPrediction=DenseVector([-0.0166, 0.0166]), count=1),
#  Row(rawPrediction=DenseVector([-0.417, 0.417]), count=1),
#  Row(rawPrediction=DenseVector([-0.6245, 0.6245]), count=1),
#  Row(rawPrediction=DenseVector([-0.5115, 0.5115]), count=1),
#  Row(rawPrediction=DenseVector([-0.5893, 0.5893]), count=1),
#  Row(rawPrediction=DenseVector([-0.0948, 0.0948]), count=1),
#  Row(rawPrediction=DenseVector([0.4865, -0.4865]), count=1),
#  Row(rawPrediction=DenseVector([3.1439, -3.1439]), count=1),
#  Row(rawPrediction=DenseVector([0.8494, -0.8494]), count=1),
#  Row(rawPrediction=DenseVector([0.844, -0.844]), count=1),
#  Row(rawPrediction=DenseVector([2.2922, -2.2922]), count=1),
#  Row(rawPrediction=DenseVector([-0.6078, 0.6078]), count=1),
#  Row(rawPrediction=DenseVector([3.1135, -3.1135]), count=1),
#  Row(rawPrediction=DenseVector([-0.7722, 0.7722]), count=1),
#  Row(rawPrediction=DenseVector([0.6555, -0.6555]), count=1),
#  Row(rawPrediction=DenseVector([0.6062, -0.6062]), count=1),
#  Row(rawPrediction=DenseVector([-1.2864, 1.2864]), count=1),
#  Row(rawPrediction=DenseVector([-0.4831, 0.4831]), count=1),
#  Row(rawPrediction=DenseVector([2.034, -2.034]), count=1),
#  Row(rawPrediction=DenseVector([1.2828, -1.2828]), count=1),
#  Row(rawPrediction=DenseVector([0.1169, -0.1169]), count=1),
#  Row(rawPrediction=DenseVector([0.032, -0.032]), count=1),
#  Row(rawPrediction=DenseVector([-1.7, 1.7]), count=1),
#  Row(rawPrediction=DenseVector([-0.3509, 0.3509]), count=1),
#  Row(rawPrediction=DenseVector([0.4427, -0.4427]), count=1),
#  Row(rawPrediction=DenseVector([0.1058, -0.1058]), count=1),
#  Row(rawPrediction=DenseVector([1.593, -1.593]), count=1),
#  Row(rawPrediction=DenseVector([2.5926, -2.5926]), count=1),
#  Row(rawPrediction=DenseVector([-0.3206, 0.3206]), count=1),
#  Row(rawPrediction=DenseVector([3.2404, -3.2404]), count=1),
#  Row(rawPrediction=DenseVector([2.8301, -2.8301]), count=1),
#  Row(rawPrediction=DenseVector([4.6803, -4.6803]), count=1),
#  Row(rawPrediction=DenseVector([-0.6858, 0.6858]), count=1),
#  Row(rawPrediction=DenseVector([1.4313, -1.4313]), count=1),
#  Row(rawPrediction=DenseVector([4.1041, -4.1041]), count=1),
#  Row(rawPrediction=DenseVector([4.4245, -4.4245]), count=1),
#  Row(rawPrediction=DenseVector([-0.414, 0.414]), count=1),
#  Row(rawPrediction=DenseVector([0.6195, -0.6195]), count=1),
#  Row(rawPrediction=DenseVector([2.2659, -2.2659]), count=1),
#  Row(rawPrediction=DenseVector([-0.8645, 0.8645]), count=1),
#  Row(rawPrediction=DenseVector([-0.2754, 0.2754]), count=1),
#  Row(rawPrediction=DenseVector([1.34, -1.34]), count=1),
#  Row(rawPrediction=DenseVector([1.8586, -1.8586]), count=1),
#  Row(rawPrediction=DenseVector([2.0142, -2.0142]), count=1),
#  Row(rawPrediction=DenseVector([-2.1704, 2.1704]), count=1),
#  Row(rawPrediction=DenseVector([-0.4482, 0.4482]), count=1),
#  Row(rawPrediction=DenseVector([-0.0536, 0.0536]), count=1),
#  Row(rawPrediction=DenseVector([-0.3196, 0.3196]), count=1),
#  Row(rawPrediction=DenseVector([0.9431, -0.9431]), count=1),
#  Row(rawPrediction=DenseVector([-1.6525, 1.6525]), count=1),
#  Row(rawPrediction=DenseVector([5.1238, -5.1238]), count=1),
#  Row(rawPrediction=DenseVector([7.7584, -7.7584]), count=1),
#  Row(rawPrediction=DenseVector([-0.201, 0.201]), count=1),
#  Row(rawPrediction=DenseVector([2.117, -2.117]), count=1),
#  Row(rawPrediction=DenseVector([1.9671, -1.9671]), count=1),
#  Row(rawPrediction=DenseVector([0.8474, -0.8474]), count=1),
#  Row(rawPrediction=DenseVector([5.7553, -5.7553]), count=1),
#  Row(rawPrediction=DenseVector([0.3853, -0.3853]), count=1),
#  Row(rawPrediction=DenseVector([1.2291, -1.2291]), count=1),
#  Row(rawPrediction=DenseVector([2.3898, -2.3898]), count=1),
#  Row(rawPrediction=DenseVector([1.7505, -1.7505]), count=1),
#  Row(rawPrediction=DenseVector([0.2231, -0.2231]), count=1),
#  Row(rawPrediction=DenseVector([0.4165, -0.4165]), count=1),
#  Row(rawPrediction=DenseVector([0.0048, -0.0048]), count=1),
#  Row(rawPrediction=DenseVector([1.2584, -1.2584]), count=1),
#  Row(rawPrediction=DenseVector([4.0568, -4.0568]), count=1),
#  Row(rawPrediction=DenseVector([2.2786, -2.2786]), count=1),
#  Row(rawPrediction=DenseVector([-0.9606, 0.9606]), count=1),
#  Row(rawPrediction=DenseVector([1.0826, -1.0826]), count=1),
#  Row(rawPrediction=DenseVector([3.0513, -3.0513]), count=1),
#  Row(rawPrediction=DenseVector([0.7232, -0.7232]), count=1),
#  Row(rawPrediction=DenseVector([0.661, -0.661]), count=1),
#  Row(rawPrediction=DenseVector([0.1461, -0.1461]), count=1),
#  Row(rawPrediction=DenseVector([1.2574, -1.2574]), count=1),
#  Row(rawPrediction=DenseVector([-0.7009, 0.7009]), count=1),
#  Row(rawPrediction=DenseVector([-1.4901, 1.4901]), count=1),
#  Row(rawPrediction=DenseVector([-0.2893, 0.2893]), count=1),
#  Row(rawPrediction=DenseVector([2.9428, -2.9428]), count=1),
#  Row(rawPrediction=DenseVector([-1.6377, 1.6377]), count=1),
#  Row(rawPrediction=DenseVector([0.27, -0.27]), count=1),
#  Row(rawPrediction=DenseVector([0.6525, -0.6525]), count=1),
#  Row(rawPrediction=DenseVector([2.2502, -2.2502]), count=1),
#  Row(rawPrediction=DenseVector([2.1135, -2.1135]), count=1),
#  Row(rawPrediction=DenseVector([-0.0406, 0.0406]), count=1),
#  Row(rawPrediction=DenseVector([-1.3938, 1.3938]), count=1),
#  Row(rawPrediction=DenseVector([0.9022, -0.9022]), count=1),
#  Row(rawPrediction=DenseVector([0.5666, -0.5666]), count=1),
#  Row(rawPrediction=DenseVector([0.252, -0.252]), count=1),
#  Row(rawPrediction=DenseVector([0.0637, -0.0637]), count=1),
#  Row(rawPrediction=DenseVector([-3.4989, 3.4989]), count=1),
#  Row(rawPrediction=DenseVector([0.702, -0.702]), count=1),
#  Row(rawPrediction=DenseVector([-0.4931, 0.4931]), count=1),
#  Row(rawPrediction=DenseVector([0.6878, -0.6878]), count=1),
#  Row(rawPrediction=DenseVector([0.3184, -0.3184]), count=1),
#  Row(rawPrediction=DenseVector([0.8139, -0.8139]), count=1),
#  Row(rawPrediction=DenseVector([-1.1598, 1.1598]), count=1),
#  Row(rawPrediction=DenseVector([2.1182, -2.1182]), count=1),
#  Row(rawPrediction=DenseVector([0.8281, -0.8281]), count=1),
#  Row(rawPrediction=DenseVector([0.6277, -0.6277]), count=1),
#  Row(rawPrediction=DenseVector([0.6613, -0.6613]), count=1),
#  Row(rawPrediction=DenseVector([-0.6631, 0.6631]), count=1),
#  Row(rawPrediction=DenseVector([-1.123, 1.123]), count=1),
#  Row(rawPrediction=DenseVector([0.2585, -0.2585]), count=1),
#  Row(rawPrediction=DenseVector([1.0806, -1.0806]), count=1),
#  Row(rawPrediction=DenseVector([-0.2533, 0.2533]), count=1),
#  Row(rawPrediction=DenseVector([4.5696, -4.5696]), count=1),
#  Row(rawPrediction=DenseVector([-3.0735, 3.0735]), count=1),
#  Row(rawPrediction=DenseVector([-0.3001, 0.3001]), count=1),
#  Row(rawPrediction=DenseVector([-0.9034, 0.9034]), count=1),
#  Row(rawPrediction=DenseVector([1.2828, -1.2828]), count=1),
#  Row(rawPrediction=DenseVector([2.844, -2.844]), count=1),
#  Row(rawPrediction=DenseVector([1.8403, -1.8403]), count=1),
#  Row(rawPrediction=DenseVector([0.189, -0.189]), count=1),
#  Row(rawPrediction=DenseVector([-0.7944, 0.7944]), count=1),
#  Row(rawPrediction=DenseVector([1.3249, -1.3249]), count=1),
#  Row(rawPrediction=DenseVector([0.4016, -0.4016]), count=1),
#  Row(rawPrediction=DenseVector([-1.2482, 1.2482]), count=1),
#  Row(rawPrediction=DenseVector([1.6349, -1.6349]), count=1),
#  Row(rawPrediction=DenseVector([1.6461, -1.6461]), count=1),
#  Row(rawPrediction=DenseVector([-0.1086, 0.1086]), count=1),
#  Row(rawPrediction=DenseVector([-0.8758, 0.8758]), count=1),
#  Row(rawPrediction=DenseVector([0.0525, -0.0525]), count=1),
#  Row(rawPrediction=DenseVector([0.4214, -0.4214]), count=1),
#  Row(rawPrediction=DenseVector([0.3155, -0.3155]), count=1),
#  Row(rawPrediction=DenseVector([1.9132, -1.9132]), count=1),
#  Row(rawPrediction=DenseVector([0.5483, -0.5483]), count=1),
#  Row(rawPrediction=DenseVector([0.9667, -0.9667]), count=1),
#  Row(rawPrediction=DenseVector([2.3016, -2.3016]), count=1),
#  Row(rawPrediction=DenseVector([-0.0141, 0.0141]), count=1),
#  Row(rawPrediction=DenseVector([3.716, -3.716]), count=1),
#  Row(rawPrediction=DenseVector([2.3789, -2.3789]), count=1),
#  Row(rawPrediction=DenseVector([1.1788, -1.1788]), count=1),
#  Row(rawPrediction=DenseVector([-0.0168, 0.0168]), count=1),
#  Row(rawPrediction=DenseVector([-1.0695, 1.0695]), count=1),
#  Row(rawPrediction=DenseVector([-0.4059, 0.4059]), count=1),
#  Row(rawPrediction=DenseVector([-0.0689, 0.0689]), count=1),
#  Row(rawPrediction=DenseVector([-0.3464, 0.3464]), count=1),
#  Row(rawPrediction=DenseVector([4.438, -4.438]), count=1),
#  Row(rawPrediction=DenseVector([4.5725, -4.5725]), count=1),
#  Row(rawPrediction=DenseVector([-0.4724, 0.4724]), count=1),
#  Row(rawPrediction=DenseVector([0.34, -0.34]), count=1),
#  Row(rawPrediction=DenseVector([1.6639, -1.6639]), count=5),
#  Row(rawPrediction=DenseVector([-0.6555, 0.6555]), count=1),
#  Row(rawPrediction=DenseVector([0.0854, -0.0854]), count=1),
#  Row(rawPrediction=DenseVector([-0.4144, 0.4144]), count=1),
#  Row(rawPrediction=DenseVector([1.3357, -1.3357]), count=1),
#  Row(rawPrediction=DenseVector([0.1651, -0.1651]), count=1),
#  Row(rawPrediction=DenseVector([1.0252, -1.0252]), count=1),
#  Row(rawPrediction=DenseVector([0.2526, -0.2526]), count=1),
#  Row(rawPrediction=DenseVector([5.2344, -5.2344]), count=1),
#  Row(rawPrediction=DenseVector([-0.0974, 0.0974]), count=1),
#  Row(rawPrediction=DenseVector([2.0701, -2.0701]), count=1),
#  Row(rawPrediction=DenseVector([1.1356, -1.1356]), count=1),
#  Row(rawPrediction=DenseVector([1.8348, -1.8348]), count=1),
#  Row(rawPrediction=DenseVector([3.8029, -3.8029]), count=1),
#  Row(rawPrediction=DenseVector([1.52, -1.52]), count=1),
#  Row(rawPrediction=DenseVector([2.4808, -2.4808]), count=1),
#  Row(rawPrediction=DenseVector([0.9699, -0.9699]), count=1),
#  Row(rawPrediction=DenseVector([0.3082, -0.3082]), count=1),
#  Row(rawPrediction=DenseVector([-0.3252, 0.3252]), count=1),
#  Row(rawPrediction=DenseVector([2.0598, -2.0598]), count=1),
#  Row(rawPrediction=DenseVector([-0.119, 0.119]), count=1),
#  Row(rawPrediction=DenseVector([2.1185, -2.1185]), count=1),
#  Row(rawPrediction=DenseVector([-0.6252, 0.6252]), count=1),
#  Row(rawPrediction=DenseVector([-1.1436, 1.1436]), count=1),
#  Row(rawPrediction=DenseVector([3.0596, -3.0596]), count=1),
#  Row(rawPrediction=DenseVector([0.026, -0.026]), count=1),
#  Row(rawPrediction=DenseVector([-0.1526, 0.1526]), count=1),
#  Row(rawPrediction=DenseVector([2.6202, -2.6202]), count=1),
#  Row(rawPrediction=DenseVector([1.9549, -1.9549]), count=1),
#  Row(rawPrediction=DenseVector([1.15, -1.15]), count=1),
#  Row(rawPrediction=DenseVector([7.0113, -7.0113]), count=1),
#  Row(rawPrediction=DenseVector([1.5861, -1.5861]), count=1),
#  Row(rawPrediction=DenseVector([0.412, -0.412]), count=1),
#  Row(rawPrediction=DenseVector([0.32, -0.32]), count=1),
#  Row(rawPrediction=DenseVector([-0.5449, 0.5449]), count=1),
#  Row(rawPrediction=DenseVector([2.6479, -2.6479]), count=1),
#  Row(rawPrediction=DenseVector([4.0873, -4.0873]), count=1),
#  Row(rawPrediction=DenseVector([5.4783, -5.4783]), count=1),
#  Row(rawPrediction=DenseVector([2.282, -2.282]), count=1),
#  Row(rawPrediction=DenseVector([0.1302, -0.1302]), count=1),
#  Row(rawPrediction=DenseVector([-0.4317, 0.4317]), count=1),
#  Row(rawPrediction=DenseVector([1.1702, -1.1702]), count=1),
#  Row(rawPrediction=DenseVector([-0.4904, 0.4904]), count=1),
#  Row(rawPrediction=DenseVector([0.9621, -0.9621]), count=1),
#  Row(rawPrediction=DenseVector([3.2172, -3.2172]), count=1),
#  Row(rawPrediction=DenseVector([0.6278, -0.6278]), count=1),
#  Row(rawPrediction=DenseVector([1.7385, -1.7385]), count=1),
#  Row(rawPrediction=DenseVector([4.3334, -4.3334]), count=1),
#  Row(rawPrediction=DenseVector([0.8232, -0.8232]), count=1),
#  Row(rawPrediction=DenseVector([0.5364, -0.5364]), count=1),
#  Row(rawPrediction=DenseVector([1.4238, -1.4238]), count=1),
#  Row(rawPrediction=DenseVector([2.822, -2.822]), count=1),
#  Row(rawPrediction=DenseVector([2.4816, -2.4816]), count=1),
#  Row(rawPrediction=DenseVector([-0.132, 0.132]), count=1),
#  Row(rawPrediction=DenseVector([-0.3287, 0.3287]), count=1),
#  Row(rawPrediction=DenseVector([3.0835, -3.0835]), count=1),
#  Row(rawPrediction=DenseVector([6.9221, -6.9221]), count=1),
#  Row(rawPrediction=DenseVector([2.6147, -2.6147]), count=1),
#  Row(rawPrediction=DenseVector([-0.3419, 0.3419]), count=1),
#  Row(rawPrediction=DenseVector([2.9987, -2.9987]), count=1),
#  Row(rawPrediction=DenseVector([4.2336, -4.2336]), count=1),
#  Row(rawPrediction=DenseVector([4.0147, -4.0147]), count=1),
#  Row(rawPrediction=DenseVector([1.4437, -1.4437]), count=1),
#  Row(rawPrediction=DenseVector([2.5146, -2.5146]), count=1),
#  Row(rawPrediction=DenseVector([-0.264, 0.264]), count=1),
#  Row(rawPrediction=DenseVector([-1.4425, 1.4425]), count=1),
#  Row(rawPrediction=DenseVector([-0.5099, 0.5099]), count=1),
#  Row(rawPrediction=DenseVector([-0.6555, 0.6555]), count=1),
#  Row(rawPrediction=DenseVector([-0.4418, 0.4418]), count=1),
#  Row(rawPrediction=DenseVector([3.1511, -3.1511]), count=1),
#  Row(rawPrediction=DenseVector([0.1407, -0.1407]), count=1),
#  Row(rawPrediction=DenseVector([1.131, -1.131]), count=1),
#  Row(rawPrediction=DenseVector([4.0064, -4.0064]), count=1),
#  Row(rawPrediction=DenseVector([-2.0749, 2.0749]), count=1),
#  Row(rawPrediction=DenseVector([0.6046, -0.6046]), count=1),
#  Row(rawPrediction=DenseVector([1.7677, -1.7677]), count=1),
#  Row(rawPrediction=DenseVector([5.4673, -5.4673]), count=1),
#  Row(rawPrediction=DenseVector([4.3182, -4.3182]), count=1),
#  Row(rawPrediction=DenseVector([7.4868, -7.4868]), count=1),
#  Row(rawPrediction=DenseVector([4.6341, -4.6341]), count=1),
#  Row(rawPrediction=DenseVector([8.8442, -8.8442]), count=1),
#  Row(rawPrediction=DenseVector([7.2098, -7.2098]), count=1),
#  Row(rawPrediction=DenseVector([2.0339, -2.0339]), count=1),
#  Row(rawPrediction=DenseVector([5.3224, -5.3224]), count=1),
#  Row(rawPrediction=DenseVector([2.9468, -2.9468]), count=1),
#  Row(rawPrediction=DenseVector([4.436, -4.436]), count=1),
#  Row(rawPrediction=DenseVector([8.9032, -8.9032]), count=1),
#  Row(rawPrediction=DenseVector([5.0528, -5.0528]), count=1),
#  Row(rawPrediction=DenseVector([4.6714, -4.6714]), count=1),
#  Row(rawPrediction=DenseVector([4.6535, -4.6535]), count=1),
#  Row(rawPrediction=DenseVector([6.1985, -6.1985]), count=1),
#  Row(rawPrediction=DenseVector([11.1103, -11.1103]), count=1),
#  Row(rawPrediction=DenseVector([4.649, -4.649]), count=1),
#  Row(rawPrediction=DenseVector([3.1879, -3.1879]), count=1),
#  Row(rawPrediction=DenseVector([2.9502, -2.9502]), count=1),
#  Row(rawPrediction=DenseVector([5.6423, -5.6423]), count=1),
#  Row(rawPrediction=DenseVector([-1.1124, 1.1124]), count=1),
#  Row(rawPrediction=DenseVector([-1.3164, 1.3164]), count=1),
#  Row(rawPrediction=DenseVector([1.3553, -1.3553]), count=1),
#  Row(rawPrediction=DenseVector([2.4533, -2.4533]), count=1),
#  Row(rawPrediction=DenseVector([0.2556, -0.2556]), count=1),
#  Row(rawPrediction=DenseVector([-0.0098, 0.0098]), count=1),
#  Row(rawPrediction=DenseVector([2.6693, -2.6693]), count=1),
#  Row(rawPrediction=DenseVector([1.209, -1.209]), count=1),
#  Row(rawPrediction=DenseVector([3.7711, -3.7711]), count=1),
#  Row(rawPrediction=DenseVector([-0.46, 0.46]), count=1),
#  Row(rawPrediction=DenseVector([1.7604, -1.7604]), count=1),
#  Row(rawPrediction=DenseVector([3.3459, -3.3459]), count=1),
#  Row(rawPrediction=DenseVector([0.6126, -0.6126]), count=1),
#  Row(rawPrediction=DenseVector([-2.6087, 2.6087]), count=1),
#  Row(rawPrediction=DenseVector([1.0828, -1.0828]), count=1),
#  Row(rawPrediction=DenseVector([1.0338, -1.0338]), count=1),
#  Row(rawPrediction=DenseVector([0.4014, -0.4014]), count=1),
#  Row(rawPrediction=DenseVector([-0.4613, 0.4613]), count=1),
#  Row(rawPrediction=DenseVector([0.8934, -0.8934]), count=1),
#  Row(rawPrediction=DenseVector([3.4513, -3.4513]), count=1),
#  Row(rawPrediction=DenseVector([0.9625, -0.9625]), count=1),
#  Row(rawPrediction=DenseVector([-0.4759, 0.4759]), count=1),
#  Row(rawPrediction=DenseVector([0.0718, -0.0718]), count=1),
#  Row(rawPrediction=DenseVector([1.7355, -1.7355]), count=1),
#  Row(rawPrediction=DenseVector([-1.6156, 1.6156]), count=1),
#  Row(rawPrediction=DenseVector([1.1097, -1.1097]), count=1),
#  Row(rawPrediction=DenseVector([0.6433, -0.6433]), count=1),
#  Row(rawPrediction=DenseVector([0.4117, -0.4117]), count=1),
#  Row(rawPrediction=DenseVector([1.0536, -1.0536]), count=1),
#  Row(rawPrediction=DenseVector([1.4729, -1.4729]), count=1),
#  Row(rawPrediction=DenseVector([-0.436, 0.436]), count=1),
#  Row(rawPrediction=DenseVector([-0.586, 0.586]), count=1),
#  Row(rawPrediction=DenseVector([-0.0943, 0.0943]), count=1),
#  Row(rawPrediction=DenseVector([3.552, -3.552]), count=1),
#  Row(rawPrediction=DenseVector([-0.9299, 0.9299]), count=1),
#  Row(rawPrediction=DenseVector([1.5005, -1.5005]), count=1),
#  Row(rawPrediction=DenseVector([2.084, -2.084]), count=1),
#  Row(rawPrediction=DenseVector([1.3335, -1.3335]), count=1),
#  Row(rawPrediction=DenseVector([-0.4429, 0.4429]), count=1),
#  Row(rawPrediction=DenseVector([4.2037, -4.2037]), count=1),
#  Row(rawPrediction=DenseVector([4.3577, -4.3577]), count=1),
#  Row(rawPrediction=DenseVector([2.6591, -2.6591]), count=1),
#  Row(rawPrediction=DenseVector([-0.4073, 0.4073]), count=1),
#  Row(rawPrediction=DenseVector([2.4043, -2.4043]), count=1),
#  Row(rawPrediction=DenseVector([3.8379, -3.8379]), count=1),
#  Row(rawPrediction=DenseVector([1.4677, -1.4677]), count=1),
#  Row(rawPrediction=DenseVector([-0.2279, 0.2279]), count=1),
#  Row(rawPrediction=DenseVector([2.3621, -2.3621]), count=1),
#  Row(rawPrediction=DenseVector([2.1346, -2.1346]), count=1),
#  Row(rawPrediction=DenseVector([1.052, -1.052]), count=1),
#  Row(rawPrediction=DenseVector([3.443, -3.443]), count=1),
#  Row(rawPrediction=DenseVector([0.1607, -0.1607]), count=1),
#  Row(rawPrediction=DenseVector([2.3386, -2.3386]), count=1),
#  Row(rawPrediction=DenseVector([0.4129, -0.4129]), count=1),
#  Row(rawPrediction=DenseVector([1.7021, -1.7021]), count=1),
#  Row(rawPrediction=DenseVector([2.4915, -2.4915]), count=1),
#  Row(rawPrediction=DenseVector([1.0261, -1.0261]), count=1),
#  Row(rawPrediction=DenseVector([0.5757, -0.5757]), count=1),
#  Row(rawPrediction=DenseVector([0.3264, -0.3264]), count=1),
#  Row(rawPrediction=DenseVector([-0.1049, 0.1049]), count=1),
#  Row(rawPrediction=DenseVector([6.3066, -6.3066]), count=1),
#  Row(rawPrediction=DenseVector([1.117, -1.117]), count=1),
#  Row(rawPrediction=DenseVector([3.4647, -3.4647]), count=1),
#  Row(rawPrediction=DenseVector([0.8264, -0.8264]), count=1),
#  Row(rawPrediction=DenseVector([2.5028, -2.5028]), count=1),
#  Row(rawPrediction=DenseVector([5.6467, -5.6467]), count=1),
#  Row(rawPrediction=DenseVector([0.3459, -0.3459]), count=1),
#  Row(rawPrediction=DenseVector([-0.2716, 0.2716]), count=1),
#  Row(rawPrediction=DenseVector([1.6371, -1.6371]), count=1),
#  Row(rawPrediction=DenseVector([-0.5976, 0.5976]), count=1),
#  Row(rawPrediction=DenseVector([-0.0195, 0.0195]), count=1),
#  Row(rawPrediction=DenseVector([1.9772, -1.9772]), count=1),
#  Row(rawPrediction=DenseVector([-1.7047, 1.7047]), count=1),
#  Row(rawPrediction=DenseVector([-0.2176, 0.2176]), count=1),
#  Row(rawPrediction=DenseVector([1.8207, -1.8207]), count=1),
#  Row(rawPrediction=DenseVector([-0.3122, 0.3122]), count=1),
#  Row(rawPrediction=DenseVector([2.3056, -2.3056]), count=1),
#  Row(rawPrediction=DenseVector([-0.1462, 0.1462]), count=1),
#  Row(rawPrediction=DenseVector([0.3682, -0.3682]), count=1),
#  Row(rawPrediction=DenseVector([2.0427, -2.0427]), count=1),
#  Row(rawPrediction=DenseVector([-1.6835, 1.6835]), count=1),
#  Row(rawPrediction=DenseVector([-1.5765, 1.5765]), count=1),
#  Row(rawPrediction=DenseVector([6.5188, -6.5188]), count=1),
#  Row(rawPrediction=DenseVector([3.0083, -3.0083]), count=1),
#  Row(rawPrediction=DenseVector([0.6374, -0.6374]), count=1),
#  Row(rawPrediction=DenseVector([0.5919, -0.5919]), count=1),
#  Row(rawPrediction=DenseVector([0.6634, -0.6634]), count=1),
#  Row(rawPrediction=DenseVector([1.0581, -1.0581]), count=1),
#  Row(rawPrediction=DenseVector([2.4257, -2.4257]), count=1),
#  Row(rawPrediction=DenseVector([3.6668, -3.6668]), count=1),
#  Row(rawPrediction=DenseVector([-0.4094, 0.4094]), count=1),
#  Row(rawPrediction=DenseVector([0.7292, -0.7292]), count=1),
#  Row(rawPrediction=DenseVector([0.808, -0.808]), count=1),
#  Row(rawPrediction=DenseVector([-0.0554, 0.0554]), count=1),
#  Row(rawPrediction=DenseVector([-0.3493, 0.3493]), count=1),
#  Row(rawPrediction=DenseVector([0.007, -0.007]), count=1),
#  Row(rawPrediction=DenseVector([-1.1283, 1.1283]), count=1),
#  Row(rawPrediction=DenseVector([2.1625, -2.1625]), count=1),
#  Row(rawPrediction=DenseVector([1.8391, -1.8391]), count=1),
#  Row(rawPrediction=DenseVector([-0.8803, 0.8803]), count=1),
#  Row(rawPrediction=DenseVector([0.3549, -0.3549]), count=1),
#  Row(rawPrediction=DenseVector([1.0624, -1.0624]), count=1),
#  Row(rawPrediction=DenseVector([1.168, -1.168]), count=1),
#  Row(rawPrediction=DenseVector([0.9885, -0.9885]), count=1),
#  Row(rawPrediction=DenseVector([-1.4, 1.4]), count=1),
#  Row(rawPrediction=DenseVector([5.0885, -5.0885]), count=1),
#  Row(rawPrediction=DenseVector([1.1515, -1.1515]), count=1),
#  Row(rawPrediction=DenseVector([0.2939, -0.2939]), count=1),
#  Row(rawPrediction=DenseVector([0.4743, -0.4743]), count=1),
#  Row(rawPrediction=DenseVector([-0.089, 0.089]), count=1),
#  Row(rawPrediction=DenseVector([1.8407, -1.8407]), count=1),
#  Row(rawPrediction=DenseVector([1.6477, -1.6477]), count=1),
#  Row(rawPrediction=DenseVector([1.3694, -1.3694]), count=1),
#  Row(rawPrediction=DenseVector([3.01, -3.01]), count=1),
#  Row(rawPrediction=DenseVector([-0.1398, 0.1398]), count=1),
#  Row(rawPrediction=DenseVector([0.3901, -0.3901]), count=1),
#  Row(rawPrediction=DenseVector([0.4609, -0.4609]), count=1),
#  Row(rawPrediction=DenseVector([1.8531, -1.8531]), count=1),
#  Row(rawPrediction=DenseVector([-0.8348, 0.8348]), count=1),
#  Row(rawPrediction=DenseVector([2.4842, -2.4842]), count=1),
#  Row(rawPrediction=DenseVector([5.1161, -5.1161]), count=1),
#  Row(rawPrediction=DenseVector([-0.3551, 0.3551]), count=4),
#  Row(rawPrediction=DenseVector([-0.5583, 0.5583]), count=1),
#  Row(rawPrediction=DenseVector([2.2689, -2.2689]), count=1),
#  Row(rawPrediction=DenseVector([-1.3844, 1.3844]), count=1),
#  Row(rawPrediction=DenseVector([-0.7992, 0.7992]), count=1),
#  Row(rawPrediction=DenseVector([5.104, -5.104]), count=1),
#  Row(rawPrediction=DenseVector([0.467, -0.467]), count=1),
#  Row(rawPrediction=DenseVector([2.4178, -2.4178]), count=1),
#  Row(rawPrediction=DenseVector([0.0126, -0.0126]), count=1),
#  Row(rawPrediction=DenseVector([-1.0016, 1.0016]), count=1),
#  Row(rawPrediction=DenseVector([1.329, -1.329]), count=1),
#  Row(rawPrediction=DenseVector([2.9054, -2.9054]), count=1),
#  Row(rawPrediction=DenseVector([-1.5277, 1.5277]), count=1),
#  Row(rawPrediction=DenseVector([2.7078, -2.7078]), count=1),
#  Row(rawPrediction=DenseVector([2.9714, -2.9714]), count=1),
#  Row(rawPrediction=DenseVector([-3.2729, 3.2729]), count=1),
#  Row(rawPrediction=DenseVector([4.4188, -4.4188]), count=1),
#  Row(rawPrediction=DenseVector([1.4401, -1.4401]), count=1),
#  Row(rawPrediction=DenseVector([3.376, -3.376]), count=1),
#  Row(rawPrediction=DenseVector([-1.1293, 1.1293]), count=1),
#  Row(rawPrediction=DenseVector([-0.2032, 0.2032]), count=1),
#  Row(rawPrediction=DenseVector([0.568, -0.568]), count=1),
#  Row(rawPrediction=DenseVector([0.3287, -0.3287]), count=1),
#  Row(rawPrediction=DenseVector([0.239, -0.239]), count=1),
#  Row(rawPrediction=DenseVector([-1.692, 1.692]), count=1),
#  Row(rawPrediction=DenseVector([0.1752, -0.1752]), count=1),
#  Row(rawPrediction=DenseVector([0.0694, -0.0694]), count=1),
#  Row(rawPrediction=DenseVector([2.3973, -2.3973]), count=1),
#  Row(rawPrediction=DenseVector([0.4252, -0.4252]), count=1),
#  Row(rawPrediction=DenseVector([-0.6841, 0.6841]), count=1),
#  Row(rawPrediction=DenseVector([-0.1292, 0.1292]), count=1),
#  Row(rawPrediction=DenseVector([0.5781, -0.5781]), count=1),
#  Row(rawPrediction=DenseVector([1.7869, -1.7869]), count=1),
#  Row(rawPrediction=DenseVector([0.6233, -0.6233]), count=1),
#  Row(rawPrediction=DenseVector([-0.3166, 0.3166]), count=1),
#  Row(rawPrediction=DenseVector([-0.6577, 0.6577]), count=1),
#  Row(rawPrediction=DenseVector([1.3514, -1.3514]), count=1),
#  Row(rawPrediction=DenseVector([-0.9046, 0.9046]), count=1),
#  Row(rawPrediction=DenseVector([-0.9033, 0.9033]), count=1),
#  Row(rawPrediction=DenseVector([3.3452, -3.3452]), count=1),
#  Row(rawPrediction=DenseVector([1.7872, -1.7872]), count=1),
#  Row(rawPrediction=DenseVector([3.0501, -3.0501]), count=1),
#  Row(rawPrediction=DenseVector([-1.2377, 1.2377]), count=1),
#  Row(rawPrediction=DenseVector([2.0665, -2.0665]), count=1),
#  Row(rawPrediction=DenseVector([0.5948, -0.5948]), count=1),
#  Row(rawPrediction=DenseVector([-0.1579, 0.1579]), count=1),
#  Row(rawPrediction=DenseVector([5.0818, -5.0818]), count=1),
#  Row(rawPrediction=DenseVector([-0.6467, 0.6467]), count=1),
#  Row(rawPrediction=DenseVector([-0.5697, 0.5697]), count=3),
#  Row(rawPrediction=DenseVector([0.3904, -0.3904]), count=1),
#  Row(rawPrediction=DenseVector([0.797, -0.797]), count=1),
#  Row(rawPrediction=DenseVector([1.1304, -1.1304]), count=1),
#  Row(rawPrediction=DenseVector([1.5485, -1.5485]), count=1),
#  Row(rawPrediction=DenseVector([0.4032, -0.4032]), count=1),
#  Row(rawPrediction=DenseVector([3.0068, -3.0068]), count=1),
#  Row(rawPrediction=DenseVector([-0.2618, 0.2618]), count=1),
#  Row(rawPrediction=DenseVector([-0.652, 0.652]), count=1),
#  Row(rawPrediction=DenseVector([-0.3563, 0.3563]), count=1),
#  Row(rawPrediction=DenseVector([-0.1351, 0.1351]), count=1),
#  Row(rawPrediction=DenseVector([-0.0623, 0.0623]), count=1),
#  Row(rawPrediction=DenseVector([3.2355, -3.2355]), count=1),
#  Row(rawPrediction=DenseVector([3.0379, -3.0379]), count=1),
#  Row(rawPrediction=DenseVector([1.6952, -1.6952]), count=1),
#  Row(rawPrediction=DenseVector([-0.85, 0.85]), count=1),
#  Row(rawPrediction=DenseVector([3.4463, -3.4463]), count=1),
#  Row(rawPrediction=DenseVector([3.0729, -3.0729]), count=1),
#  Row(rawPrediction=DenseVector([1.3473, -1.3473]), count=1),
#  Row(rawPrediction=DenseVector([0.3161, -0.3161]), count=1),
#  Row(rawPrediction=DenseVector([2.0232, -2.0232]), count=1),
#  Row(rawPrediction=DenseVector([4.8758, -4.8758]), count=1),
#  Row(rawPrediction=DenseVector([-0.3463, 0.3463]), count=1),
#  Row(rawPrediction=DenseVector([3.1533, -3.1533]), count=1),
#  Row(rawPrediction=DenseVector([0.8454, -0.8454]), count=1),
#  Row(rawPrediction=DenseVector([2.5359, -2.5359]), count=1),
#  Row(rawPrediction=DenseVector([-0.3773, 0.3773]), count=1),
#  Row(rawPrediction=DenseVector([1.1456, -1.1456]), count=1),
#  Row(rawPrediction=DenseVector([-0.1006, 0.1006]), count=1),
#  Row(rawPrediction=DenseVector([3.6996, -3.6996]), count=1),
#  Row(rawPrediction=DenseVector([-1.1855, 1.1855]), count=1),
#  Row(rawPrediction=DenseVector([0.1459, -0.1459]), count=1),
#  Row(rawPrediction=DenseVector([4.4477, -4.4477]), count=1),
#  Row(rawPrediction=DenseVector([-0.2077, 0.2077]), count=1),
#  Row(rawPrediction=DenseVector([0.0546, -0.0546]), count=1),
#  Row(rawPrediction=DenseVector([0.9215, -0.9215]), count=1),
#  Row(rawPrediction=DenseVector([0.756, -0.756]), count=1),
#  Row(rawPrediction=DenseVector([0.7572, -0.7572]), count=1),
#  Row(rawPrediction=DenseVector([2.4074, -2.4074]), count=1),
#  Row(rawPrediction=DenseVector([-1.0548, 1.0548]), count=1),
#  Row(rawPrediction=DenseVector([-1.8955, 1.8955]), count=1),
#  Row(rawPrediction=DenseVector([-1.5282, 1.5282]), count=1),
#  Row(rawPrediction=DenseVector([-0.4531, 0.4531]), count=1),
#  Row(rawPrediction=DenseVector([1.5373, -1.5373]), count=1),
#  Row(rawPrediction=DenseVector([0.5729, -0.5729]), count=1),
#  Row(rawPrediction=DenseVector([-0.1965, 0.1965]), count=1),
#  Row(rawPrediction=DenseVector([3.8041, -3.8041]), count=1),
#  Row(rawPrediction=DenseVector([0.0568, -0.0568]), count=1),
#  Row(rawPrediction=DenseVector([4.3838, -4.3838]), count=1),
#  Row(rawPrediction=DenseVector([5.8065, -5.8065]), count=1),
#  Row(rawPrediction=DenseVector([0.4919, -0.4919]), count=1),
#  Row(rawPrediction=DenseVector([1.6753, -1.6753]), count=1),
#  Row(rawPrediction=DenseVector([-1.4175, 1.4175]), count=1),
#  Row(rawPrediction=DenseVector([0.9701, -0.9701]), count=1),
#  Row(rawPrediction=DenseVector([-1.7391, 1.7391]), count=1),
#  Row(rawPrediction=DenseVector([-0.4068, 0.4068]), count=1),
#  Row(rawPrediction=DenseVector([5.303, -5.303]), count=1),
#  Row(rawPrediction=DenseVector([2.1909, -2.1909]), count=1),
#  Row(rawPrediction=DenseVector([0.3784, -0.3784]), count=1),
#  Row(rawPrediction=DenseVector([-0.8981, 0.8981]), count=1),
#  Row(rawPrediction=DenseVector([0.2584, -0.2584]), count=1),
#  Row(rawPrediction=DenseVector([0.2639, -0.2639]), count=1),
#  Row(rawPrediction=DenseVector([1.901, -1.901]), count=1),
#  Row(rawPrediction=DenseVector([0.8178, -0.8178]), count=1),
#  Row(rawPrediction=DenseVector([0.2684, -0.2684]), count=1),
#  Row(rawPrediction=DenseVector([0.5538, -0.5538]), count=1),
#  Row(rawPrediction=DenseVector([2.1714, -2.1714]), count=1),
#  Row(rawPrediction=DenseVector([-1.0246, 1.0246]), count=1),
#  Row(rawPrediction=DenseVector([0.3313, -0.3313]), count=1),
#  Row(rawPrediction=DenseVector([2.3703, -2.3703]), count=1),
#  Row(rawPrediction=DenseVector([0.5518, -0.5518]), count=1),
#  Row(rawPrediction=DenseVector([-0.4466, 0.4466]), count=1),
#  Row(rawPrediction=DenseVector([-0.2936, 0.2936]), count=1),
#  Row(rawPrediction=DenseVector([-0.4007, 0.4007]), count=1),
#  Row(rawPrediction=DenseVector([0.0514, -0.0514]), count=1),
#  Row(rawPrediction=DenseVector([3.5248, -3.5248]), count=1),
#  Row(rawPrediction=DenseVector([4.883, -4.883]), count=1),
#  Row(rawPrediction=DenseVector([1.064, -1.064]), count=1),
#  Row(rawPrediction=DenseVector([2.8181, -2.8181]), count=1),
#  Row(rawPrediction=DenseVector([1.864, -1.864]), count=1),
#  Row(rawPrediction=DenseVector([3.8953, -3.8953]), count=1),
#  Row(rawPrediction=DenseVector([1.8821, -1.8821]), count=1),
#  Row(rawPrediction=DenseVector([2.9295, -2.9295]), count=1),
#  Row(rawPrediction=DenseVector([0.009, -0.009]), count=1),
#  Row(rawPrediction=DenseVector([0.2952, -0.2952]), count=1),
#  Row(rawPrediction=DenseVector([1.0504, -1.0504]), count=1),
#  Row(rawPrediction=DenseVector([-0.4865, 0.4865]), count=1),
#  Row(rawPrediction=DenseVector([0.8553, -0.8553]), count=1),
#  Row(rawPrediction=DenseVector([-0.5181, 0.5181]), count=1),
#  Row(rawPrediction=DenseVector([2.0517, -2.0517]), count=1),
#  Row(rawPrediction=DenseVector([4.5011, -4.5011]), count=1),
#  Row(rawPrediction=DenseVector([0.6704, -0.6704]), count=1),
#  Row(rawPrediction=DenseVector([-1.0653, 1.0653]), count=1),
#  Row(rawPrediction=DenseVector([2.191, -2.191]), count=1),
#  Row(rawPrediction=DenseVector([0.2941, -0.2941]), count=1),
#  Row(rawPrediction=DenseVector([-0.6439, 0.6439]), count=1),
#  Row(rawPrediction=DenseVector([3.2731, -3.2731]), count=1),
#  Row(rawPrediction=DenseVector([0.1413, -0.1413]), count=1),
#  Row(rawPrediction=DenseVector([1.1993, -1.1993]), count=1),
#  Row(rawPrediction=DenseVector([2.7331, -2.7331]), count=1),
#  Row(rawPrediction=DenseVector([5.1381, -5.1381]), count=1),
#  Row(rawPrediction=DenseVector([0.3437, -0.3437]), count=1),
#  Row(rawPrediction=DenseVector([0.2771, -0.2771]), count=1),
#  Row(rawPrediction=DenseVector([3.0729, -3.0729]), count=1),
#  Row(rawPrediction=DenseVector([0.318, -0.318]), count=1),
#  Row(rawPrediction=DenseVector([1.552, -1.552]), count=1),
#  Row(rawPrediction=DenseVector([2.2157, -2.2157]), count=1),
#  Row(rawPrediction=DenseVector([-0.7561, 0.7561]), count=1),
#  Row(rawPrediction=DenseVector([0.9033, -0.9033]), count=1),
#  Row(rawPrediction=DenseVector([1.8928, -1.8928]), count=1),
#  Row(rawPrediction=DenseVector([-0.5618, 0.5618]), count=1),
#  Row(rawPrediction=DenseVector([1.52, -1.52]), count=1),
#  Row(rawPrediction=DenseVector([-0.8192, 0.8192]), count=1),
#  Row(rawPrediction=DenseVector([-0.0785, 0.0785]), count=1),
#  Row(rawPrediction=DenseVector([0.2802, -0.2802]), count=1),
#  Row(rawPrediction=DenseVector([7.5894, -7.5894]), count=1),
#  Row(rawPrediction=DenseVector([0.1895, -0.1895]), count=1),
#  Row(rawPrediction=DenseVector([-0.6536, 0.6536]), count=1),
#  Row(rawPrediction=DenseVector([1.0659, -1.0659]), count=1),
#  Row(rawPrediction=DenseVector([0.3027, -0.3027]), count=1),
#  Row(rawPrediction=DenseVector([7.5422, -7.5422]), count=1),
#  Row(rawPrediction=DenseVector([-0.9148, 0.9148]), count=1),
#  Row(rawPrediction=DenseVector([-0.7695, 0.7695]), count=1),
#  Row(rawPrediction=DenseVector([0.231, -0.231]), count=1),
#  Row(rawPrediction=DenseVector([4.1424, -4.1424]), count=1),
#  Row(rawPrediction=DenseVector([1.1509, -1.1509]), count=1),
#  Row(rawPrediction=DenseVector([2.2711, -2.2711]), count=1),
#  Row(rawPrediction=DenseVector([2.6144, -2.6144]), count=1),
#  Row(rawPrediction=DenseVector([0.9052, -0.9052]), count=1),
#  Row(rawPrediction=DenseVector([0.3959, -0.3959]), count=1),
#  Row(rawPrediction=DenseVector([1.1701, -1.1701]), count=1),
#  Row(rawPrediction=DenseVector([0.2726, -0.2726]), count=1),
#  Row(rawPrediction=DenseVector([1.1548, -1.1548]), count=1),
#  Row(rawPrediction=DenseVector([-1.2336, 1.2336]), count=1),
#  Row(rawPrediction=DenseVector([1.3182, -1.3182]), count=1),
#  Row(rawPrediction=DenseVector([-0.65, 0.65]), count=1),
#  Row(rawPrediction=DenseVector([2.2654, -2.2654]), count=1),
#  Row(rawPrediction=DenseVector([0.0776, -0.0776]), count=1),
#  Row(rawPrediction=DenseVector([-0.4156, 0.4156]), count=1),
#  Row(rawPrediction=DenseVector([0.832, -0.832]), count=1),
#  Row(rawPrediction=DenseVector([2.6989, -2.6989]), count=1),
#  Row(rawPrediction=DenseVector([-0.633, 0.633]), count=1),
#  Row(rawPrediction=DenseVector([1.1902, -1.1902]), count=1),
#  Row(rawPrediction=DenseVector([0.47, -0.47]), count=1),
#  Row(rawPrediction=DenseVector([5.1474, -5.1474]), count=1),
#  Row(rawPrediction=DenseVector([2.5403, -2.5403]), count=1),
#  Row(rawPrediction=DenseVector([0.9144, -0.9144]), count=1),
#  Row(rawPrediction=DenseVector([3.4667, -3.4667]), count=1),
#  Row(rawPrediction=DenseVector([2.6992, -2.6992]), count=1),
#  Row(rawPrediction=DenseVector([-0.8855, 0.8855]), count=1),
#  Row(rawPrediction=DenseVector([-1.2903, 1.2903]), count=1),
#  Row(rawPrediction=DenseVector([0.7949, -0.7949]), count=1),
#  Row(rawPrediction=DenseVector([7.6646, -7.6646]), count=1),
#  Row(rawPrediction=DenseVector([-2.568, 2.568]), count=1),
#  Row(rawPrediction=DenseVector([1.8331, -1.8331]), count=1),
#  Row(rawPrediction=DenseVector([-0.6348, 0.6348]), count=1),
#  Row(rawPrediction=DenseVector([-0.5868, 0.5868]), count=1),
#  Row(rawPrediction=DenseVector([-0.6227, 0.6227]), count=1),
#  Row(rawPrediction=DenseVector([-3.172, 3.172]), count=1),
#  Row(rawPrediction=DenseVector([0.5419, -0.5419]), count=1),
#  Row(rawPrediction=DenseVector([-0.8586, 0.8586]), count=1),
#  Row(rawPrediction=DenseVector([1.2725, -1.2725]), count=1),
#  Row(rawPrediction=DenseVector([2.5876, -2.5876]), count=1),
#  Row(rawPrediction=DenseVector([-0.0012, 0.0012]), count=1),
#  Row(rawPrediction=DenseVector([-1.1972, 1.1972]), count=1),
#  Row(rawPrediction=DenseVector([1.158, -1.158]), count=1),
#  Row(rawPrediction=DenseVector([2.2042, -2.2042]), count=1),
#  Row(rawPrediction=DenseVector([0.4983, -0.4983]), count=1),
#  Row(rawPrediction=DenseVector([1.5992, -1.5992]), count=1),
#  Row(rawPrediction=DenseVector([4.1054, -4.1054]), count=1),
#  Row(rawPrediction=DenseVector([3.4373, -3.4373]), count=1),
#  Row(rawPrediction=DenseVector([2.6902, -2.6902]), count=1),
#  Row(rawPrediction=DenseVector([2.3649, -2.3649]), count=1),
#  Row(rawPrediction=DenseVector([2.2641, -2.2641]), count=1),
#  Row(rawPrediction=DenseVector([1.7165, -1.7165]), count=1),
#  Row(rawPrediction=DenseVector([-0.0706, 0.0706]), count=1),
#  Row(rawPrediction=DenseVector([-0.7063, 0.7063]), count=1),
#  Row(rawPrediction=DenseVector([3.259, -3.259]), count=1),
#  Row(rawPrediction=DenseVector([3.1606, -3.1606]), count=1),
#  Row(rawPrediction=DenseVector([0.9781, -0.9781]), count=1),
#  Row(rawPrediction=DenseVector([-0.0227, 0.0227]), count=1),
#  Row(rawPrediction=DenseVector([1.2297, -1.2297]), count=1),
#  Row(rawPrediction=DenseVector([-0.5911, 0.5911]), count=1),
#  Row(rawPrediction=DenseVector([-0.0128, 0.0128]), count=1),
#  Row(rawPrediction=DenseVector([-1.4169, 1.4169]), count=1),
#  Row(rawPrediction=DenseVector([2.2011, -2.2011]), count=1),
#  Row(rawPrediction=DenseVector([-0.6696, 0.6696]), count=1),
#  Row(rawPrediction=DenseVector([0.7813, -0.7813]), count=1),
#  Row(rawPrediction=DenseVector([3.7457, -3.7457]), count=1),
#  Row(rawPrediction=DenseVector([1.4759, -1.4759]), count=1),
#  Row(rawPrediction=DenseVector([-0.6561, 0.6561]), count=1),
#  Row(rawPrediction=DenseVector([1.926, -1.926]), count=1),
#  Row(rawPrediction=DenseVector([0.2949, -0.2949]), count=1),
#  Row(rawPrediction=DenseVector([2.2113, -2.2113]), count=1),
#  Row(rawPrediction=DenseVector([4.2499, -4.2499]), count=1),
#  Row(rawPrediction=DenseVector([0.1091, -0.1091]), count=1),
#  Row(rawPrediction=DenseVector([1.9865, -1.9865]), count=1),
#  Row(rawPrediction=DenseVector([1.0083, -1.0083]), count=1),
#  Row(rawPrediction=DenseVector([2.4437, -2.4437]), count=1),
#  Row(rawPrediction=DenseVector([2.2481, -2.2481]), count=1),
#  Row(rawPrediction=DenseVector([3.4426, -3.4426]), count=1),
#  Row(rawPrediction=DenseVector([0.5008, -0.5008]), count=1),
#  Row(rawPrediction=DenseVector([3.9359, -3.9359]), count=1),
#  Row(rawPrediction=DenseVector([-2.2217, 2.2217]), count=1),
#  Row(rawPrediction=DenseVector([-0.2819, 0.2819]), count=1),
#  Row(rawPrediction=DenseVector([3.4811, -3.4811]), count=1),
#  Row(rawPrediction=DenseVector([1.7615, -1.7615]), count=1),
#  Row(rawPrediction=DenseVector([1.4307, -1.4307]), count=1),
#  Row(rawPrediction=DenseVector([-0.0918, 0.0918]), count=1),
#  Row(rawPrediction=DenseVector([3.1936, -3.1936]), count=1),
#  Row(rawPrediction=DenseVector([1.9408, -1.9408]), count=1),
#  Row(rawPrediction=DenseVector([0.6644, -0.6644]), count=1),
#  Row(rawPrediction=DenseVector([2.5947, -2.5947]), count=1),
#  Row(rawPrediction=DenseVector([0.8021, -0.8021]), count=1),
#  Row(rawPrediction=DenseVector([0.1512, -0.1512]), count=1),
#  Row(rawPrediction=DenseVector([-0.4553, 0.4553]), count=1),
#  Row(rawPrediction=DenseVector([1.8289, -1.8289]), count=1),
#  Row(rawPrediction=DenseVector([-0.5954, 0.5954]), count=1),
#  Row(rawPrediction=DenseVector([0.4845, -0.4845]), count=1),
#  Row(rawPrediction=DenseVector([0.0937, -0.0937]), count=1),
#  Row(rawPrediction=DenseVector([2.8586, -2.8586]), count=1),
#  Row(rawPrediction=DenseVector([3.0643, -3.0643]), count=1),
#  Row(rawPrediction=DenseVector([9.1936, -9.1936]), count=1),
#  Row(rawPrediction=DenseVector([3.7263, -3.7263]), count=1),
#  Row(rawPrediction=DenseVector([5.2792, -5.2792]), count=1),
#  Row(rawPrediction=DenseVector([0.3004, -0.3004]), count=1),
#  Row(rawPrediction=DenseVector([-0.5355, 0.5355]), count=1),
#  Row(rawPrediction=DenseVector([-0.706, 0.706]), count=1),
#  Row(rawPrediction=DenseVector([2.4071, -2.4071]), count=1),
#  Row(rawPrediction=DenseVector([3.8495, -3.8495]), count=1),
#  Row(rawPrediction=DenseVector([-0.8836, 0.8836]), count=1),
#  Row(rawPrediction=DenseVector([2.6096, -2.6096]), count=1),
#  Row(rawPrediction=DenseVector([0.601, -0.601]), count=1),
#  Row(rawPrediction=DenseVector([1.2907, -1.2907]), count=1),
#  Row(rawPrediction=DenseVector([0.8047, -0.8047]), count=1),
#  Row(rawPrediction=DenseVector([0.4647, -0.4647]), count=1),
#  Row(rawPrediction=DenseVector([-1.1293, 1.1293]), count=1),
#  Row(rawPrediction=DenseVector([0.504, -0.504]), count=1),
#  Row(rawPrediction=DenseVector([3.4272, -3.4272]), count=1),
#  Row(rawPrediction=DenseVector([-0.5516, 0.5516]), count=1),
#  Row(rawPrediction=DenseVector([-0.0548, 0.0548]), count=1),
#  Row(rawPrediction=DenseVector([1.0271, -1.0271]), count=1),
#  Row(rawPrediction=DenseVector([2.3758, -2.3758]), count=1),
#  Row(rawPrediction=DenseVector([1.1337, -1.1337]), count=1),
#  Row(rawPrediction=DenseVector([4.8383, -4.8383]), count=1),
#  Row(rawPrediction=DenseVector([3.4518, -3.4518]), count=1),
#  Row(rawPrediction=DenseVector([1.1709, -1.1709]), count=1),
#  Row(rawPrediction=DenseVector([1.2172, -1.2172]), count=1),
#  Row(rawPrediction=DenseVector([-0.5555, 0.5555]), count=1),
#  Row(rawPrediction=DenseVector([0.4165, -0.4165]), count=1),
#  Row(rawPrediction=DenseVector([-0.8412, 0.8412]), count=1),
#  Row(rawPrediction=DenseVector([-1.4001, 1.4001]), count=1),
#  Row(rawPrediction=DenseVector([-0.2949, 0.2949]), count=1),
#  Row(rawPrediction=DenseVector([1.809, -1.809]), count=1),
#  Row(rawPrediction=DenseVector([0.0824, -0.0824]), count=1),
#  Row(rawPrediction=DenseVector([-0.3529, 0.3529]), count=1),
#  Row(rawPrediction=DenseVector([0.1391, -0.1391]), count=1),
#  Row(rawPrediction=DenseVector([1.5978, -1.5978]), count=1),
#  Row(rawPrediction=DenseVector([-1.1422, 1.1422]), count=1),
#  Row(rawPrediction=DenseVector([0.6727, -0.6727]), count=1),
#  Row(rawPrediction=DenseVector([-0.7744, 0.7744]), count=1),
#  Row(rawPrediction=DenseVector([1.5933, -1.5933]), count=1),
#  Row(rawPrediction=DenseVector([1.8154, -1.8154]), count=1),
#  Row(rawPrediction=DenseVector([-0.5397, 0.5397]), count=1),
#  Row(rawPrediction=DenseVector([0.4726, -0.4726]), count=1),
#  Row(rawPrediction=DenseVector([-0.691, 0.691]), count=1),
#  Row(rawPrediction=DenseVector([0.2811, -0.2811]), count=1),
#  Row(rawPrediction=DenseVector([0.5012, -0.5012]), count=1),
#  Row(rawPrediction=DenseVector([-0.8803, 0.8803]), count=1),
#  Row(rawPrediction=DenseVector([-0.2449, 0.2449]), count=1),
#  Row(rawPrediction=DenseVector([1.2869, -1.2869]), count=1),
#  Row(rawPrediction=DenseVector([-0.1756, 0.1756]), count=1),
#  Row(rawPrediction=DenseVector([-0.6125, 0.6125]), count=1),
#  Row(rawPrediction=DenseVector([-1.1471, 1.1471]), count=1),
#  Row(rawPrediction=DenseVector([1.3115, -1.3115]), count=1),
#  Row(rawPrediction=DenseVector([2.9167, -2.9167]), count=1),
#  Row(rawPrediction=DenseVector([0.2792, -0.2792]), count=1),
#  Row(rawPrediction=DenseVector([2.4403, -2.4403]), count=1),
#  Row(rawPrediction=DenseVector([3.3312, -3.3312]), count=1),
#  Row(rawPrediction=DenseVector([5.9693, -5.9693]), count=1),
#  Row(rawPrediction=DenseVector([0.0345, -0.0345]), count=1),
#  Row(rawPrediction=DenseVector([2.64, -2.64]), count=1),
#  Row(rawPrediction=DenseVector([-1.0611, 1.0611]), count=1),
#  Row(rawPrediction=DenseVector([3.6475, -3.6475]), count=1),
#  Row(rawPrediction=DenseVector([-1.3335, 1.3335]), count=1),
#  Row(rawPrediction=DenseVector([-2.1986, 2.1986]), count=1),
#  Row(rawPrediction=DenseVector([-0.4652, 0.4652]), count=1),
#  Row(rawPrediction=DenseVector([-1.2552, 1.2552]), count=1),
#  Row(rawPrediction=DenseVector([1.8546, -1.8546]), count=1),
#  Row(rawPrediction=DenseVector([-0.4416, 0.4416]), count=2),
#  Row(rawPrediction=DenseVector([-0.0461, 0.0461]), count=1),
#  Row(rawPrediction=DenseVector([1.7487, -1.7487]), count=1),
#  Row(rawPrediction=DenseVector([6.7141, -6.7141]), count=1),
#  Row(rawPrediction=DenseVector([0.4222, -0.4222]), count=1),
#  Row(rawPrediction=DenseVector([-2.4617, 2.4617]), count=1),
#  Row(rawPrediction=DenseVector([-0.0394, 0.0394]), count=1),
#  Row(rawPrediction=DenseVector([-2.5674, 2.5674]), count=1),
#  Row(rawPrediction=DenseVector([1.6412, -1.6412]), count=1),
#  Row(rawPrediction=DenseVector([-0.5351, 0.5351]), count=1),
#  Row(rawPrediction=DenseVector([0.1419, -0.1419]), count=1),
#  Row(rawPrediction=DenseVector([1.7901, -1.7901]), count=1),
#  Row(rawPrediction=DenseVector([0.148, -0.148]), count=1),
#  Row(rawPrediction=DenseVector([2.3652, -2.3652]), count=1),
#  Row(rawPrediction=DenseVector([-2.1733, 2.1733]), count=1),
#  Row(rawPrediction=DenseVector([-0.6115, 0.6115]), count=1),
#  Row(rawPrediction=DenseVector([-0.2373, 0.2373]), count=1),
#  Row(rawPrediction=DenseVector([3.4721, -3.4721]), count=1),
#  Row(rawPrediction=DenseVector([-0.3635, 0.3635]), count=1),
#  Row(rawPrediction=DenseVector([4.795, -4.795]), count=1),
#  Row(rawPrediction=DenseVector([5.8242, -5.8242]), count=1),
#  Row(rawPrediction=DenseVector([1.5693, -1.5693]), count=1),
#  Row(rawPrediction=DenseVector([1.7033, -1.7033]), count=1),
#  Row(rawPrediction=DenseVector([8.3372, -8.3372]), count=1),
#  Row(rawPrediction=DenseVector([0.8801, -0.8801]), count=1),
#  Row(rawPrediction=DenseVector([3.6442, -3.6442]), count=1),
#  Row(rawPrediction=DenseVector([2.5873, -2.5873]), count=1),
#  Row(rawPrediction=DenseVector([1.2444, -1.2444]), count=1),
#  Row(rawPrediction=DenseVector([-1.7492, 1.7492]), count=1),
#  Row(rawPrediction=DenseVector([-0.7319, 0.7319]), count=1),
#  Row(rawPrediction=DenseVector([-1.9215, 1.9215]), count=1),
#  Row(rawPrediction=DenseVector([1.3184, -1.3184]), count=1),
#  Row(rawPrediction=DenseVector([-0.2084, 0.2084]), count=1),
#  Row(rawPrediction=DenseVector([-0.6368, 0.6368]), count=1),
#  Row(rawPrediction=DenseVector([2.3412, -2.3412]), count=1),
#  Row(rawPrediction=DenseVector([0.4664, -0.4664]), count=1),
#  Row(rawPrediction=DenseVector([1.4619, -1.4619]), count=1),
#  Row(rawPrediction=DenseVector([3.4839, -3.4839]), count=1),
#  Row(rawPrediction=DenseVector([1.3399, -1.3399]), count=1),
#  Row(rawPrediction=DenseVector([2.8512, -2.8512]), count=1),
#  Row(rawPrediction=DenseVector([-0.5317, 0.5317]), count=1),
#  Row(rawPrediction=DenseVector([0.9185, -0.9185]), count=1),
#  Row(rawPrediction=DenseVector([2.6397, -2.6397]), count=1),
#  Row(rawPrediction=DenseVector([1.5773, -1.5773]), count=1),
#  Row(rawPrediction=DenseVector([0.0889, -0.0889]), count=1),
#  Row(rawPrediction=DenseVector([2.1397, -2.1397]), count=1),
#  Row(rawPrediction=DenseVector([1.4556, -1.4556]), count=1),
#  Row(rawPrediction=DenseVector([0.7612, -0.7612]), count=1),
#  Row(rawPrediction=DenseVector([1.9944, -1.9944]), count=4),
#  Row(rawPrediction=DenseVector([1.8239, -1.8239]), count=1),
#  Row(rawPrediction=DenseVector([5.442, -5.442]), count=1),
#  Row(rawPrediction=DenseVector([3.5769, -3.5769]), count=1),
#  Row(rawPrediction=DenseVector([8.7359, -8.7359]), count=1),
#  Row(rawPrediction=DenseVector([2.6331, -2.6331]), count=1),
#  Row(rawPrediction=DenseVector([8.5675, -8.5675]), count=1),
#  Row(rawPrediction=DenseVector([5.9822, -5.9822]), count=1),
#  Row(rawPrediction=DenseVector([11.2492, -11.2492]), count=1),
#  Row(rawPrediction=DenseVector([6.0213, -6.0213]), count=1),
#  Row(rawPrediction=DenseVector([3.2627, -3.2627]), count=1),
#  Row(rawPrediction=DenseVector([5.782, -5.782]), count=1),
#  Row(rawPrediction=DenseVector([4.6088, -4.6088]), count=1),
#  Row(rawPrediction=DenseVector([4.4133, -4.4133]), count=1),
#  Row(rawPrediction=DenseVector([2.6766, -2.6766]), count=1),
#  Row(rawPrediction=DenseVector([6.6416, -6.6416]), count=1),
#  Row(rawPrediction=DenseVector([5.851, -5.851]), count=1),
#  Row(rawPrediction=DenseVector([6.0331, -6.0331]), count=1),
#  Row(rawPrediction=DenseVector([4.1651, -4.1651]), count=1),
#  Row(rawPrediction=DenseVector([0.3808, -0.3808]), count=1),
#  Row(rawPrediction=DenseVector([4.5295, -4.5295]), count=1),
#  Row(rawPrediction=DenseVector([5.2405, -5.2405]), count=1),
#  Row(rawPrediction=DenseVector([0.9571, -0.9571]), count=1),
#  Row(rawPrediction=DenseVector([4.1895, -4.1895]), count=1),
#  Row(rawPrediction=DenseVector([0.7247, -0.7247]), count=1),
#  Row(rawPrediction=DenseVector([-0.2888, 0.2888]), count=1),
#  Row(rawPrediction=DenseVector([-0.3327, 0.3327]), count=2),
#  Row(rawPrediction=DenseVector([5.8601, -5.8601]), count=1),
#  Row(rawPrediction=DenseVector([3.2248, -3.2248]), count=1),
#  Row(rawPrediction=DenseVector([-0.2533, 0.2533]), count=1),
#  Row(rawPrediction=DenseVector([-0.8379, 0.8379]), count=1),
#  Row(rawPrediction=DenseVector([-0.2549, 0.2549]), count=1),
#  Row(rawPrediction=DenseVector([1.6345, -1.6345]), count=1),
#  Row(rawPrediction=DenseVector([0.2171, -0.2171]), count=1),
#  Row(rawPrediction=DenseVector([-0.3053, 0.3053]), count=1),
#  Row(rawPrediction=DenseVector([0.0007, -0.0007]), count=1),
#  Row(rawPrediction=DenseVector([2.8343, -2.8343]), count=1),
#  Row(rawPrediction=DenseVector([-0.2, 0.2]), count=1),
#  Row(rawPrediction=DenseVector([3.885, -3.885]), count=1),
#  Row(rawPrediction=DenseVector([0.6596, -0.6596]), count=1),
#  Row(rawPrediction=DenseVector([3.1049, -3.1049]), count=1),
#  Row(rawPrediction=DenseVector([0.1293, -0.1293]), count=1),
#  Row(rawPrediction=DenseVector([1.1854, -1.1854]), count=1),
#  Row(rawPrediction=DenseVector([5.7193, -5.7193]), count=1),
#  Row(rawPrediction=DenseVector([8.0401, -8.0401]), count=1),
#  Row(rawPrediction=DenseVector([4.5114, -4.5114]), count=1),
#  Row(rawPrediction=DenseVector([3.3734, -3.3734]), count=1),
#  Row(rawPrediction=DenseVector([5.6899, -5.6899]), count=1),
#  Row(rawPrediction=DenseVector([3.0262, -3.0262]), count=1),
#  Row(rawPrediction=DenseVector([1.5476, -1.5476]), count=1),
#  Row(rawPrediction=DenseVector([3.1245, -3.1245]), count=1),
#  Row(rawPrediction=DenseVector([1.3094, -1.3094]), count=1),
#  Row(rawPrediction=DenseVector([-0.1804, 0.1804]), count=1),
#  Row(rawPrediction=DenseVector([-0.0915, 0.0915]), count=3),
#  Row(rawPrediction=DenseVector([-0.4446, 0.4446]), count=1),
#  Row(rawPrediction=DenseVector([1.1926, -1.1926]), count=1),
#  Row(rawPrediction=DenseVector([-0.4973, 0.4973]), count=1),
#  Row(rawPrediction=DenseVector([0.0487, -0.0487]), count=1),
#  Row(rawPrediction=DenseVector([0.0729, -0.0729]), count=1),
#  Row(rawPrediction=DenseVector([1.1643, -1.1643]), count=1),
#  Row(rawPrediction=DenseVector([8.4996, -8.4996]), count=1),
#  Row(rawPrediction=DenseVector([-0.3467, 0.3467]), count=1),
#  Row(rawPrediction=DenseVector([1.8247, -1.8247]), count=1),
#  Row(rawPrediction=DenseVector([-0.6055, 0.6055]), count=1),
#  Row(rawPrediction=DenseVector([4.3404, -4.3404]), count=1),
#  Row(rawPrediction=DenseVector([2.4232, -2.4232]), count=1),
#  Row(rawPrediction=DenseVector([0.7777, -0.7777]), count=1),
#  Row(rawPrediction=DenseVector([0.2451, -0.2451]), count=1),
#  Row(rawPrediction=DenseVector([6.7748, -6.7748]), count=1),
#  Row(rawPrediction=DenseVector([9.121, -9.121]), count=1),
#  Row(rawPrediction=DenseVector([6.9704, -6.9704]), count=1),
#  Row(rawPrediction=DenseVector([1.1477, -1.1477]), count=1),
#  Row(rawPrediction=DenseVector([-1.5816, 1.5816]), count=1),
#  Row(rawPrediction=DenseVector([-1.0527, 1.0527]), count=1),
#  Row(rawPrediction=DenseVector([3.9493, -3.9493]), count=1),
#  Row(rawPrediction=DenseVector([2.5304, -2.5304]), count=1),
#  Row(rawPrediction=DenseVector([-0.4503, 0.4503]), count=1),
#  Row(rawPrediction=DenseVector([0.5443, -0.5443]), count=1),
#  Row(rawPrediction=DenseVector([2.505, -2.505]), count=1),
#  Row(rawPrediction=DenseVector([2.4334, -2.4334]), count=1),
#  Row(rawPrediction=DenseVector([2.1372, -2.1372]), count=1),
#  Row(rawPrediction=DenseVector([1.3545, -1.3545]), count=1),
#  Row(rawPrediction=DenseVector([0.0204, -0.0204]), count=1),
#  Row(rawPrediction=DenseVector([0.0676, -0.0676]), count=1),
#  Row(rawPrediction=DenseVector([0.05, -0.05]), count=1),
#  Row(rawPrediction=DenseVector([2.8797, -2.8797]), count=1),
#  Row(rawPrediction=DenseVector([0.0603, -0.0603]), count=1),
#  Row(rawPrediction=DenseVector([0.9665, -0.9665]), count=1),
#  Row(rawPrediction=DenseVector([-0.8058, 0.8058]), count=1),
#  Row(rawPrediction=DenseVector([1.1589, -1.1589]), count=1),
#  Row(rawPrediction=DenseVector([1.8911, -1.8911]), count=1),
#  Row(rawPrediction=DenseVector([0.4467, -0.4467]), count=1),
#  Row(rawPrediction=DenseVector([3.6214, -3.6214]), count=1),
#  Row(rawPrediction=DenseVector([3.8695, -3.8695]), count=1),
#  Row(rawPrediction=DenseVector([0.1375, -0.1375]), count=1),
#  Row(rawPrediction=DenseVector([-0.3419, 0.3419]), count=1),
#  Row(rawPrediction=DenseVector([-0.1544, 0.1544]), count=1),
#  Row(rawPrediction=DenseVector([1.005, -1.005]), count=1),
#  Row(rawPrediction=DenseVector([0.946, -0.946]), count=1),
#  Row(rawPrediction=DenseVector([6.1975, -6.1975]), count=1),
#  Row(rawPrediction=DenseVector([1.531, -1.531]), count=1),
#  Row(rawPrediction=DenseVector([-0.4369, 0.4369]), count=1),
#  Row(rawPrediction=DenseVector([3.5946, -3.5946]), count=1),
#  Row(rawPrediction=DenseVector([4.2515, -4.2515]), count=1),
#  Row(rawPrediction=DenseVector([-0.1535, 0.1535]), count=1),
#  Row(rawPrediction=DenseVector([3.9965, -3.9965]), count=1),
#  Row(rawPrediction=DenseVector([0.9821, -0.9821]), count=1),
#  Row(rawPrediction=DenseVector([-0.9225, 0.9225]), count=1),
#  Row(rawPrediction=DenseVector([2.9902, -2.9902]), count=1),
#  Row(rawPrediction=DenseVector([1.4854, -1.4854]), count=1),
#  Row(rawPrediction=DenseVector([3.3523, -3.3523]), count=1),
#  Row(rawPrediction=DenseVector([3.4929, -3.4929]), count=1),
#  Row(rawPrediction=DenseVector([-1.1381, 1.1381]), count=1),
#  Row(rawPrediction=DenseVector([2.0957, -2.0957]), count=1),
#  Row(rawPrediction=DenseVector([1.8551, -1.8551]), count=1),
#  Row(rawPrediction=DenseVector([7.7321, -7.7321]), count=1),
#  Row(rawPrediction=DenseVector([0.25, -0.25]), count=1),
#  Row(rawPrediction=DenseVector([0.4179, -0.4179]), count=1),
#  Row(rawPrediction=DenseVector([-0.1122, 0.1122]), count=1),
#  Row(rawPrediction=DenseVector([2.4439, -2.4439]), count=1),
#  Row(rawPrediction=DenseVector([2.6542, -2.6542]), count=1),
#  Row(rawPrediction=DenseVector([-0.6162, 0.6162]), count=1),
#  Row(rawPrediction=DenseVector([3.2896, -3.2896]), count=1),
#  Row(rawPrediction=DenseVector([1.7692, -1.7692]), count=1),
#  Row(rawPrediction=DenseVector([-0.336, 0.336]), count=1),
#  Row(rawPrediction=DenseVector([2.7354, -2.7354]), count=1),
#  Row(rawPrediction=DenseVector([0.108, -0.108]), count=1),
#  Row(rawPrediction=DenseVector([0.8269, -0.8269]), count=1),
#  Row(rawPrediction=DenseVector([5.5788, -5.5788]), count=1),
#  Row(rawPrediction=DenseVector([0.0407, -0.0407]), count=1),
#  Row(rawPrediction=DenseVector([-0.57, 0.57]), count=1),
#  Row(rawPrediction=DenseVector([2.8927, -2.8927]), count=1),
#  Row(rawPrediction=DenseVector([0.4563, -0.4563]), count=1),
#  Row(rawPrediction=DenseVector([-0.3483, 0.3483]), count=1),
#  Row(rawPrediction=DenseVector([-0.4618, 0.4618]), count=1),
#  Row(rawPrediction=DenseVector([1.7057, -1.7057]), count=1),
#  Row(rawPrediction=DenseVector([2.8967, -2.8967]), count=1),
#  Row(rawPrediction=DenseVector([1.6479, -1.6479]), count=1),
#  Row(rawPrediction=DenseVector([1.1151, -1.1151]), count=1),
#  Row(rawPrediction=DenseVector([2.2486, -2.2486]), count=1),
#  Row(rawPrediction=DenseVector([-0.1357, 0.1357]), count=1),
#  Row(rawPrediction=DenseVector([2.7162, -2.7162]), count=1),
#  Row(rawPrediction=DenseVector([2.2816, -2.2816]), count=1),
#  Row(rawPrediction=DenseVector([4.0932, -4.0932]), count=1),
#  Row(rawPrediction=DenseVector([4.0018, -4.0018]), count=1),
#  Row(rawPrediction=DenseVector([1.9275, -1.9275]), count=1),
#  Row(rawPrediction=DenseVector([0.5199, -0.5199]), count=1),
#  Row(rawPrediction=DenseVector([0.4835, -0.4835]), count=1),
#  Row(rawPrediction=DenseVector([1.6977, -1.6977]), count=1),
#  Row(rawPrediction=DenseVector([4.1762, -4.1762]), count=1),
#  Row(rawPrediction=DenseVector([4.5106, -4.5106]), count=1),
#  Row(rawPrediction=DenseVector([1.2799, -1.2799]), count=1),
#  Row(rawPrediction=DenseVector([-0.7308, 0.7308]), count=1),
#  Row(rawPrediction=DenseVector([1.909, -1.909]), count=1),
#  Row(rawPrediction=DenseVector([2.366, -2.366]), count=1),
#  Row(rawPrediction=DenseVector([-0.2391, 0.2391]), count=1),
#  Row(rawPrediction=DenseVector([0.3627, -0.3627]), count=1),
#  Row(rawPrediction=DenseVector([0.0214, -0.0214]), count=1),
#  Row(rawPrediction=DenseVector([1.4031, -1.4031]), count=1),
#  Row(rawPrediction=DenseVector([0.5684, -0.5684]), count=1),
#  Row(rawPrediction=DenseVector([1.182, -1.182]), count=1),
#  Row(rawPrediction=DenseVector([2.3246, -2.3246]), count=1),
#  Row(rawPrediction=DenseVector([1.887, -1.887]), count=1),
#  Row(rawPrediction=DenseVector([2.0417, -2.0417]), count=1),
#  Row(rawPrediction=DenseVector([3.7837, -3.7837]), count=1),
#  Row(rawPrediction=DenseVector([0.0129, -0.0129]), count=1),
#  Row(rawPrediction=DenseVector([-0.0296, 0.0296]), count=1),
#  Row(rawPrediction=DenseVector([3.3311, -3.3311]), count=1),
#  Row(rawPrediction=DenseVector([-0.5656, 0.5656]), count=1),
#  Row(rawPrediction=DenseVector([0.0132, -0.0132]), count=1),
#  Row(rawPrediction=DenseVector([0.8695, -0.8695]), count=1),
#  Row(rawPrediction=DenseVector([1.3345, -1.3345]), count=1),
#  Row(rawPrediction=DenseVector([-0.6494, 0.6494]), count=1),
#  Row(rawPrediction=DenseVector([6.4888, -6.4888]), count=1),
#  Row(rawPrediction=DenseVector([0.0239, -0.0239]), count=1),
#  Row(rawPrediction=DenseVector([2.0652, -2.0652]), count=1),
#  Row(rawPrediction=DenseVector([0.1263, -0.1263]), count=1),
#  Row(rawPrediction=DenseVector([2.5061, -2.5061]), count=1),
#  Row(rawPrediction=DenseVector([4.0703, -4.0703]), count=1),
#  Row(rawPrediction=DenseVector([0.6151, -0.6151]), count=1),
#  Row(rawPrediction=DenseVector([1.0305, -1.0305]), count=1),
#  Row(rawPrediction=DenseVector([5.2564, -5.2564]), count=1),
#  Row(rawPrediction=DenseVector([-1.626, 1.626]), count=1),
#  Row(rawPrediction=DenseVector([0.1937, -0.1937]), count=1),
#  Row(rawPrediction=DenseVector([1.4412, -1.4412]), count=1),
#  Row(rawPrediction=DenseVector([1.6598, -1.6598]), count=1),
#  Row(rawPrediction=DenseVector([-1.0452, 1.0452]), count=1),
#  Row(rawPrediction=DenseVector([2.1553, -2.1553]), count=1),
#  Row(rawPrediction=DenseVector([0.1047, -0.1047]), count=1),
#  Row(rawPrediction=DenseVector([0.5212, -0.5212]), count=1),
#  Row(rawPrediction=DenseVector([2.9128, -2.9128]), count=1),
#  Row(rawPrediction=DenseVector([1.2389, -1.2389]), count=1),
#  Row(rawPrediction=DenseVector([-0.7242, 0.7242]), count=1),
#  Row(rawPrediction=DenseVector([2.0439, -2.0439]), count=1),
#  Row(rawPrediction=DenseVector([-0.9746, 0.9746]), count=1),
#  Row(rawPrediction=DenseVector([-0.4352, 0.4352]), count=1),
#  Row(rawPrediction=DenseVector([0.4982, -0.4982]), count=1),
#  Row(rawPrediction=DenseVector([0.4643, -0.4643]), count=1),
#  Row(rawPrediction=DenseVector([-0.1228, 0.1228]), count=1),
#  Row(rawPrediction=DenseVector([1.1277, -1.1277]), count=1),
#  Row(rawPrediction=DenseVector([-0.2853, 0.2853]), count=1),
#  Row(rawPrediction=DenseVector([5.8959, -5.8959]), count=1),
#  Row(rawPrediction=DenseVector([0.9069, -0.9069]), count=1),
#  ...]

# %% [markdown]
# sauvegarder le modele

# %%
training.save("\model_lr")
